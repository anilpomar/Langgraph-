# %%
from langgraph import StarGraph,END
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langgraph import StarGraph,END
#
# ImportError: cannot import name 'StarGraph' from 'langgraph' (unknown location)
